# %%
import six
import sys
sys.modules['sklearn.externals.six'] = six
import mlrose_hiive
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn import metrics
from sklearn.model_selection import validation_curve
from sklearn.model_selection import learning_curve
from sklearn.metrics import accuracy_score
from sklearn.metrics import log_loss
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score

#getting the data set
data=pd.read_csv('brain_stroke.csv',index_col=0)
data.head(-5)
#print(data)
#print(data.isna().sum())
#print(data.info())

# Importing LabelEncoder
from sklearn.preprocessing import LabelEncoder
# Instantiating LabelEncoder
le=LabelEncoder()
# Iterating over all the values of each column and extract their dtypes
for col in data.columns.to_numpy():
    # Comparing if the dtype is object
    if data[col].dtypes in ('object','category'):
    # Using LabelEncoder to do the numeric transformation
        data[col]=le.fit_transform(data[col].astype(str))


#establishing the training set and the test set
x=data.drop(["stroke"],axis=1)
y=data["stroke"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42,stratify=y)
x_train.shape, x_test.shape

# Normalize feature data
scaler = MinMaxScaler()

x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)
import time
startTime = time.time()
# Initialize neural network object and fit object - attempt 1
nn_model1 = mlrose_hiive.NeuralNetwork(hidden_nodes = [100], activation ='relu', 
                                 algorithm ='random_hill_climb', restarts= 10, curve=True,
                                 max_iters = 1000, bias = True, is_classifier = True, 
                                 learning_rate = 0.01, early_stopping = False, 
                                 clip_max = 50, max_attempts = 1000, random_state = 42)

nn_model1.fit(x_train_scaled, y_train)
# Predict labels for train set and assess accuracy
y_train_pred = nn_model1.predict(x_train_scaled)

y_train_accuracy = accuracy_score(y_train, y_train_pred)

print(y_train_accuracy)
executionTime = (time.time() - startTime)
print('Execution time in seconds: ' + str(executionTime))

# Predict labels for train set and assess accuracy
y_train_pred = nn_model1.predict(x_train_scaled)

y_train_accuracy = accuracy_score(y_train, y_train_pred)

print(y_train_accuracy)
# Out:
# 0.05909351692484223
# Execution time in seconds: 97.09565663337708
# 0.05909351692484223

# %%
loss_curve=nn_model1.fitness_curve[:,0]

# %%
plt.plot(loss_curve)

# %%
list_mutation=[10,30,50,60,80]
for i in list_mutation:
    nn_model1 = mlrose_hiive.NeuralNetwork(hidden_nodes = [100], activation ='relu', 
                                 algorithm ='random_hill_climb', curve=True, restarts=i,
                                 max_iters = 2000, bias = True, is_classifier = True,  
                                 learning_rate = 0.01, early_stopping = False, 
                                 clip_max = 50, max_attempts = 2000, random_state = 42)
    nn_model1.fit(x_train_scaled, y_train)
    if i==10:
        color='blue'
    if i==30:
        color='red'
    if i==50:
        color='green'
    if i==60:
        color='black'
    if i==80:
        color='orange'
    loss_curve=nn_model1.fitness_curve[:,0]
    plt.plot(loss_curve,marker='o', markersize=2,color=color, label=('GA_mutation_prob_'+str(i)))
    plt.xlabel('Number of iterations')
    plt.ylabel('loss score')
    plt.legend(loc='lower right')
    plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [26], in <cell line: 2>()
#       2 for i in list_mutation:
#       3     nn_model1 = mlrose_hiive.NeuralNetwork(hidden_nodes = [100], activation ='relu',
#       4                                  algorithm ='random_hill_climb', curve=True, restarts=i,
#       5                                  max_iters = 2000, bias = True, is_classifier = True,
#       6                                  learning_rate = 0.01, early_stopping = False,
#       7                                  clip_max = 50, max_attempts = 2000, random_state = 42)
# ----> 8     nn_model1.fit(x_train_scaled, y_train)
#       9     if i==10:
#      10         color='blue'
#
# File ~\anaconda3\lib\site-packages\mlrose_hiive\neural\_nn_core.py:153, in _NNCore.fit(self, X, y, init_weights)
#     144 fitness, problem = self._build_problem_and_fitness_function(X, y,
#     145                                                             node_list,
#     146                                                             self.activation_dict[self.activation],
#    (...)
#     149                                                             self.clip_max,
#     150                                                             self.is_classifier)
#     152 if self.algorithm == 'random_hill_climb':
# --> 153     fitness_curve, fitted_weights, loss = self.__run_with_rhc(init_weights, num_nodes, problem)
#     155 elif self.algorithm == 'simulated_annealing':
#     156     fitness_curve, fitted_weights, loss = self._run_with_sa(init_weights, num_nodes, problem)
#
# File ~\anaconda3\lib\site-packages\mlrose_hiive\neural\_nn_core.py:243, in _NNCore.__run_with_rhc(self, init_weights, num_nodes, problem)
#     239     init_weights = np.random.uniform(-1, 1, num_nodes)
#     241 if self.curve:
#     242     current_weights, current_loss, fitness_curve = \
# --> 243         random_hill_climb(problem,
#     244                           max_attempts=self.max_attempts if
#     245                           self.early_stopping else
#     246                           self.max_iters,
#     247                           max_iters=self.max_iters,
#     248                           restarts=0, init_state=init_weights,
#     249                           curve=self.curve)
#     250 else:
#     251     current_weights, current_loss, _ = random_hill_climb(
#     252         problem,
#     253         max_attempts=self.max_attempts if self.early_stopping
#     254         else self.max_iters,
#     255         max_iters=self.max_iters,
#     256         restarts=0, init_state=init_weights, curve=self.curve)
#
# File ~\anaconda3\lib\site-packages\mlrose_hiive\algorithms\rhc.py:127, in random_hill_climb(problem, max_attempts, max_iters, restarts, init_state, curve, random_state, state_fitness_callback, callback_user_info)
#     125 current_fitness = problem.get_fitness()
#     126 if next_fitness > current_fitness:
# --> 127     problem.set_state(next_state)
#     128     attempts = 0
#     129 else:
#
# File ~\anaconda3\lib\site-packages\mlrose_hiive\opt_probs\_opt_prob.py:240, in _OptProb.set_state(self, new_state)
#     237     raise Exception("""new_state length must match problem length""")
#     239 self.state = new_state
# --> 240 self.fitness = self.eval_fitness(self.state)
#
# File ~\anaconda3\lib\site-packages\mlrose_hiive\opt_probs\_opt_prob.py:98, in _OptProb.eval_fitness(self, state)
#      95 if len(state) != self.length:
#      96     raise Exception("state length must match problem length")
# ---> 98 fitness = self.maximize*self.fitness_fn.evaluate(state)
#      99 # increment fevals for the current iteration
#     100 self.fitness_evaluations += 1
#
# File ~\anaconda3\lib\site-packages\mlrose_hiive\neural\fitness\network_weights.py:142, in NetworkWeights.evaluate(self, state)
#     140 # Transform outputs to get inputs for next layer (or final preds)
#     141 if i < len(self.weights) - 1:
# --> 142     inputs = self.activation(outputs)
#     143 else:
#     144     self.y_pred = self.output_activation(outputs)
#
# File ~\anaconda3\lib\site-packages\mlrose_hiive\neural\activation\relu.py:32, in relu(x, deriv)
#      15 """ReLU activation function
#      16
#      17 Parameters
#    (...)
#      29     Value of activation function at x
#      30 """
#      31 fx = np.copy(x)
# ---> 32 fx[np.where(fx < 0)] = 0
#      34 if deriv:
#      35     fx[np.where(fx > 0)] = 1
#
# File <__array_function__ internals>:5, in where(*args, **kwargs)
#
# KeyboardInterrupt:
